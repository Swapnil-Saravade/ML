# %%
import pandas as pd
import sklearn 
import numpy 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Glass.csv")

# %%
df.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
df.isna().sum()
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %%
df.shape
# Out:
# (214, 10)

# %%
print(df.isnull().sum())
print("="*30)
print(df["Type"].unique())
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64
# ...
# [1 2 3 5 6 7]

# %%
df.sample(10)
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba    Fe  Type
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.00     1
# 140  1.51690  13.33  3.54  1.61  72.54  0.68  8.11  0.00  0.00     2
# 23   1.51751  12.81  3.57  1.35  73.02  0.62  8.59  0.00  0.00     1
# 128  1.52068  13.55  2.09  1.67  72.18  0.53  9.57  0.27  0.17     2
# 176  1.51905  14.00  2.39  1.56  72.37  0.00  9.57  0.00  0.00     6
# 33   1.51753  12.57  3.47  1.38  73.39  0.60  8.55  0.00  0.06     1
# 27   1.51721  12.87  3.48  1.33  73.04  0.56  8.43  0.00  0.00     1
# 79   1.51590  12.82  3.52  1.90  72.86  0.69  7.97  0.00  0.00     2
# 115  1.51846  13.41  3.89  1.33  72.38  0.51  8.28  0.00  0.00     2
# 84   1.51409  14.25  3.09  2.08  72.28  1.10  7.08  0.00  0.00     2

# %%
df.describe().T
# Out:
#       count       mean       std       min        25%       50%        75%  \
# RI    214.0   1.518365  0.003037   1.51115   1.516522   1.51768   1.519157
# Na    214.0  13.407850  0.816604  10.73000  12.907500  13.30000  13.825000
# Mg    214.0   2.684533  1.442408   0.00000   2.115000   3.48000   3.600000
# Al    214.0   1.444907  0.499270   0.29000   1.190000   1.36000   1.630000
# Si    214.0  72.650935  0.774546  69.81000  72.280000  72.79000  73.087500
# K     214.0   0.497056  0.652192   0.00000   0.122500   0.55500   0.610000
# Ca    214.0   8.956963  1.423153   5.43000   8.240000   8.60000   9.172500
# Ba    214.0   0.175047  0.497219   0.00000   0.000000   0.00000   0.000000
# Fe    214.0   0.057009  0.097439   0.00000   0.000000   0.00000   0.100000
# Type  214.0   2.780374  2.103739   1.00000   1.000000   2.00000   3.000000
#
#            max
# RI     1.53393
# Na    17.38000
# Mg     4.49000
# Al     3.50000
# Si    75.41000
# K      6.21000
# Ca    16.19000
# ...

# %%
df.plot(kind='density', subplots=True, layout=(4,5), figsize=(13,20), sharex=False, sharey=False)
plt.show()

# %%
df.plot(kind='box', subplots=True, layout=(4,5), figsize=(13,20), sharex=False, sharey=False)
plt.show()

# %%
df5=df.iloc[:, :-1]
df6=df.iloc[:,-1]

# %%
df5
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0
#
# [214 rows x 9 columns]

# %%
df6
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 209    7
# 210    7
# 211    7
# 212    7
# 213    7
# Name: Type, Length: 214, dtype: int64

# %%
df5.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
model=scaler.fit(df5)
scaled_data=model.transform(df5)

# %%
print(scaled_data)
# Out:
# [[0.43283582 0.43759398 1.         ... 0.30855019 0.         0.        ]
#  [0.28358209 0.47518797 0.80178174 ... 0.22304833 0.         0.        ]
#  [0.22080773 0.42105263 0.79064588 ... 0.21840149 0.         0.        ]
#  ...
#  [0.41703248 0.54586466 0.         ... 0.27973978 0.52063492 0.        ]
#  [0.23529412 0.54887218 0.         ... 0.28345725 0.4984127  0.        ]
#  [0.26163301 0.52631579 0.         ... 0.2964684  0.53015873 0.        ]]

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split
x_train, X_test, y_train, y_test = train_test_split(scaled_data,df6, test_size=0.3, random_state=0)

# %%
K_=[]
pred_=[]
score_=[]
for k in range(2,100):
    K_.append(k)
    model= KNeighborsClassifier(n_neighbors=k)
    model.fit(x_train, y_train)
    pred=model.predict(X_test)
    pred_.append(pred)
    acc=accuracy_score(y_test,pred)
    score_.append(acc)

# %%
plt.scatter(K_,score_)
plt.show()

# %%
numpy.array(score_)
# Out:
# array([0.73846154, 0.73846154, 0.69230769, 0.61538462, 0.69230769,
#        0.63076923, 0.63076923, 0.61538462, 0.61538462, 0.69230769,
#        0.67692308, 0.66153846, 0.63076923, 0.66153846, 0.63076923,
#        0.61538462, 0.64615385, 0.63076923, 0.64615385, 0.66153846,
#        0.58461538, 0.58461538, 0.50769231, 0.52307692, 0.52307692,
#        0.55384615, 0.53846154, 0.53846154, 0.52307692, 0.53846154,
#        0.50769231, 0.50769231, 0.49230769, 0.47692308, 0.46153846,
#        0.47692308, 0.47692308, 0.50769231, 0.47692308, 0.52307692,
#        0.52307692, 0.52307692, 0.56923077, 0.58461538, 0.58461538,
#        0.58461538, 0.58461538, 0.55384615, 0.56923077, 0.55384615,
#        0.58461538, 0.55384615, 0.53846154, 0.52307692, 0.52307692,
#        0.43076923, 0.50769231, 0.50769231, 0.49230769, 0.50769231,
#        0.44615385, 0.46153846, 0.38461538, 0.4       , 0.44615385,
#        0.50769231, 0.43076923, 0.47692308, 0.47692308, 0.4       ,
# ...

# %%
import numpy as np
k_values = np.arange(1,25)
train_accuracy = []
test_accuracy = []

# %%
for i, k in enumerate(k_values):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(x_train,y_train)
    train_accuracy.append(knn.score(x_train, y_train))
    test_accuracy.append(knn.score(X_test, y_test))

# %%
plt.figure(figsize=[13,8])
plt.plot(k_values, test_accuracy, label = 'Testing Accuracy')
plt.plot(k_values, train_accuracy, label = 'Training Accuracy')
plt.legend()
plt.title('-value VS Accuracy')
plt.xlabel('Number of Neighbors')
plt.ylabel('Accuracy')
plt.xticks(k_values)
plt.show()

# %%
knn = KNeighborsClassifier(n_neighbors=4)
knn.fit(x_train, y_train)
y_pred_KNeighborsClassifier = knn.predict(X_test)

# %%
scores = []
cv_scores = []

# %%
from sklearn.metrics import accuracy_score
score = accuracy_score(y_pred_KNeighborsClassifier,y_test)
scores.append(score)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred_KNeighborsClassifier,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.95      0.56      0.70        36
#            2       0.54      0.82      0.65        17
#            3       0.14      1.00      0.25         1
#            5       0.50      0.50      0.50         2
#            6       1.00      1.00      1.00         2
#            7       1.00      1.00      1.00         7
#
#     accuracy                           0.69        65
#    macro avg       0.69      0.81      0.68        65
# weighted avg       0.82      0.69      0.72        65
